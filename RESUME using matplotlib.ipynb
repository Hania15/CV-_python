# %%
# Importing necessary libraries
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox

# Setting font style
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

# Creating a figure and axis
fig, ax = plt.subplots(figsize=(8.5, 11))

# Adding decorative lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# Setting background color
ax.set_facecolor('white')

# Removing axes
plt.axis('off')

# Adding text annotations
# Header
plt.annotate('>>>This resume was generated entirely in Python. For full sourcecode, view my portfolio.', (.02, .98), weight='regular', fontsize=8, alpha=.75)

# Personal Information
plt.annotate('Hanna Trepkowska', (.02, .94), weight='bold', fontsize=20)
plt.annotate('Analytics Consumption Engineer', (.02, .91), weight='regular', fontsize=14)
plt.annotate('Bydgoszcz \n www.linkedin.com/in/\n hanna-trepkowska-a71467290\n/https://github.com/Hania15', (.7, .906), weight='regular', fontsize=8, color='#ffffff')

# Projects
plt.annotate('PROJECTS/PUBLICATIONS', (.02, .86), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate('Tableau report creation', (.02, .832), weight='bold', fontsize=10)
plt.annotate('- Taken out the data from Kaggle\n- Analyzed data to find valuable insights\n- Cleaned/visualized data using pandas/matplotlib libraries in Python', (.04, .78), weight='regular', fontsize=9)

# Work Experience
plt.annotate('EXPERIENCE', (.02, .75), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate('Arla Foods | Analytics Consumption Engineer', (.02, .730), weight='bold', fontsize=10)
plt.annotate('''Maintanance of created solutions of data flows in Azure - Databricks, Azure Data Factory
- Automation of processes related to support of Power BI reports  
Power Automate - update SP list when new item appears on mailbox
- Understand HOTOed reports - identify slow performance
on visuals tuning reports and removing possible issues
- Support of tickets issued by standard users and developers
resolving potential connection issues,
  gateway issues and keeping users updated about good practice of creating reports
- Working closely with standard users and certified developers to maintain stable process''', (.04, .575), weight='regular', fontsize=9)

plt.annotate('Atos / Eviden | BI Developer\ Junior Data Enginner', (.02, .55), weight='bold', fontsize=10)
plt.annotate("""Writing simple ETL processes in DataBricks using Python - getting ready for role ETL engineer
Using data transformation with DataBricks Notebook using Python (PySpark and Pandas)
Conducted regular root cause analyses to improve performance, 
tuning in reports and Azure pipelines
Working with the Azure Cloud (Data Factory, Logic Apps, 
Analyses Services, Storages, KeyValuts, DataBricks)
Built out the reporting infrastructure from the ground up using PowerBI/Tableau 
and Azure (Data Factory, Logic Apps) to provide real time insights and wrote calculated columns, 
measures, queries in Power Bi desktop to show correct Key Performance Indicators (KPI)
Building the solutions to transform and copy the data from source 
to destination using Azure Cloud (Data Factory, Analysis Services, Key Vault, Logic App, DataBricks) 
Hands-on experience in MS SQL to write queries and procedures across large volumes of data""", (.04, .425), weight='regular', fontsize=9)


plt.annotate('Atos / Eviden | Business Specialist', (.02, .35), weight='bold', fontsize=10)
plt.annotate("""Participating in creation and forming financial internal tool content 
(including new entries, corrections, data transfer from current Excel's)
Active working in automation initiatives - work on purchase orders, service orders, 
reviewing financial document's related to security services 
Managing and updating financial report in Power Bi
Creating ad-hoc reports using Excel/VBA """, (.04, .300), weight='regular', fontsize=9, )



# Education
plt.annotate('EDUCATION', (.02, .230), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate("""Technical University in Bydgoszcz, 
Master of Computer Science in Business 
Postgraduate school - Project Manager """, (.04, .180), weight='regular', fontsize=9)

# Skills
plt.annotate('Skills', (.7, .85), weight='bold', fontsize=10, color='#ffffff')
plt.annotate('- Python\n- Pandas\n- NumPy\n- Data Visualization\n- Data Cleaning\n- Command Line\n- Git and Version Control\n- SQL\n- APIs\n- Probability/Statistics\n- Data Manipulation\n- Excel', (.7, .63), weight='regular', fontsize=10, color='#ffffff')

# Extras
plt.annotate('Data Analyst\nData Engineer Path', (.7, .45), weight='bold', fontsize=10, color='mediumseagreen')
plt.annotate('Learned data science\nlanguages, data cleaning and\nmanipulation, machine learning \nand statistical analysis\nI especially loved the \nvisualization libraries ', (.7, .345), weight='regular', fontsize=10, color='mediumseagreen',)

# Code Title (Corrected)
plt.annotate('Analytics Consumption Engineer', (.7, .2), weight='bold', fontsize=10, color='#ffffff')

# Saving the figure
#plt.savefig('Haniacvex.pdf', dpi=300, bbox_inches='tight')
# Out:
# Text(0.7, 0.2, 'Analytics Consumption Engineer')

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

# Build a rectangle in axes coords
left, width = .15, .6
bottom, height = .15, .6
right = left + width
top = bottom + height
p = plt.Rectangle((left, bottom), width, height, fill=False)
p.set_transform(ax.transAxes)
p.set_clip_on(False)
ax.add_patch(p)

ax.text(0.5 * (left + right), 0.5 * (bottom + top), """middle xxxshgdvcshdgvchsgdvchgsdvchsgvdchsgvchgdvchgs
djfvjdhbvjdbfj
defhvbihefb
edfvdfv
vefdv""",
        horizontalalignment='center',
        verticalalignment='center',
        transform=ax.transAxes)


#ax.set_axis_off()

plt.show()
