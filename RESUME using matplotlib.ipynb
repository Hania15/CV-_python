# %%
# Importing necessary libraries
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg


# Setting font style
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

# Creating a figure and axis
fig, ax = plt.subplots(figsize=(8.5, 11))

# Adding decorative lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=250)
plt.axhline(y=.88, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# Setting background color
ax.set_facecolor('white')

# Removing axes
plt.axis('on')

# Adding text annotations
# Header
plt.annotate('>>>This resume was generated entirely in Python. For full sourcecode, view my portfolio.', (.02, .98), weight='regular', fontsize=8, alpha=.75)

# Personal Information
plt.annotate('Hanna Trepkowska', (.02, .94), weight='bold', fontsize=20)
plt.annotate('Analytics Consumption Engineer', (.02, .91), weight='regular', fontsize=14)
plt.annotate('Bydgoszcz \n www.linkedin.com/in/\n hanna-trepkowska-a71467290\n/https://github.com/Hania15', (.75, .906), weight='regular', fontsize=8, color='#ffffff')


plt.annotate('About me:', (.02, .88), weight='bold', fontsize=10, color='skyblue')
# Text with wrapping
text = """
  Passionate about turning data into stories! 
  Skilled in Power BI, Tableau, cloud integration, SQL, and Python data libraries
"""

ax.text(0.01, 0.85, text,
        horizontalalignment='left',
        verticalalignment='center',
        bbox=dict(boxstyle="round,pad=0.3", edgecolor="none", facecolor="none"),
        wrap=True)

# Work Experience
plt.annotate('EXPERIENCE', (.02, .80), weight='bold', fontsize=10, color='skyblue')
plt.annotate('Arla | Analytics Consumption Engineer', (.02, .780), weight='bold', fontsize=10)
# Text with wrapping
text = """
- maintanance of created solutions of data flows in Azure like Databricks and ADF
- automation of processes related to support of Power BI reports Power Automate 
- update SP list when new item appears on mailbox
- understand HOTOed reports - identify slow performance on visuals 
- tuning reports and removing possible issues
- support of tickets issued by standard users and developers 
- resolving potential connection issue along with gateway issues 
- working closely with standard users and certified developers to maintain stable 
  process"""

ax.text(0.01, 0.70, text,
        horizontalalignment='left',
        verticalalignment='center',
        bbox=dict(boxstyle="round,pad=0.3", edgecolor="none", facecolor="none"),
        wrap=True)



plt.annotate('Atos/Eviden | BI Developer/Junior Data Engineer', (.02, .575), weight='bold', fontsize=10)
text = """
- writing simple ETL processes in DataBricks using Python - getting ready 
  for role ETL engineer
- using data transformation with DataBricks Notebook using Python
  (PySpark and Pandas)
- conducted regular root cause analyses to improve performance, tuning in reports 
  and Azure pipelines
- working with the Azure Cloud (Data Factory, Logic Apps, Analyses Services, 
  Storages, KeyValuts, DataBricks)
- built out the reporting infrastructure from the ground up using PowerBI/Tableau 
  and Azure (Data Factory, Logic Apps) to provide real time insights 
  and wrote calculated columns, measures, queries in Power Bi desktop 
  to show correct Key Performance Indicators (KPI)
- building the solutions to transform and copy the data from source to destination 
  using Azure Cloud (Data Factory, Analysis Services, Key Vault, 
  Logic App, DataBricks) 
- hands-on experience in MS SQL to write queries and procedures 
  across large volumes of data"""

ax.text(0.01, 0.42, text,
        horizontalalignment='left',
        verticalalignment='center',
        bbox=dict(boxstyle="round,pad=0.3", edgecolor="none", facecolor="none"),
        wrap=True)


plt.annotate('Atos/Eviden | Business Specialist', (.02, .225), weight='bold', fontsize=10)
text = """
- participating in creation and forming financial internal tool content 
  (including new entries, corrections, data transfer from current Excel's)
- active working in automation initiatives - work on purchase orders, service orders, 
  reviewing financial document's related to security services 
- managing and updating financial report in Power Bi
- creating ad-hoc reports using Excel/VBA """
             
ax.text(0.01, 0.17, text,
        horizontalalignment='left',
        verticalalignment='center',
        bbox=dict(boxstyle="round,pad=0.3", edgecolor="none", facecolor="none"),
        wrap=True)



# Education
plt.annotate('Education', (.02, .085), weight='bold', fontsize=10, color='skyblue')
text = """
  Technical University in Bydgoszcz - BA Finance and Accounting, 
  MA of Computer Science in Business 
  Postgraduate school - Project Manager """

ax.text(0.01, 0.06, text,
        horizontalalignment='left',
        verticalalignment='center',
        bbox=dict(boxstyle="round,pad=0.3", edgecolor="none", facecolor="none"),
        wrap=True)


# Skills
plt.annotate('Skills', (.85, .85), weight='bold', fontsize=10, color='#ffffff')
plt.annotate('- Python\n- Pandas\n- NumPy\n- Data Visualization\n- Data Cleaning\n- Command Line\n- Git and Version Control\n- SQL\n- APIs\n- Probability/Statistics\n- Data Manipulation\n- Excel', (.75, .63), weight='regular', fontsize=10, color='skyblue')

# Extras
plt.annotate('Data Analyst\nData Engineer Path', (.75, .45), weight='bold', fontsize=10, color='skyblue')
plt.annotate("""Learned data languages- 
data manipulation, cleaning 
along with basics of 
machine learning with 
statistical analysis.
I especially loved the
visualization libraries """, (.75, .280), weight='regular', fontsize=10, color='skyblue',)


# Saving the figure
plt.savefig('Hania_resume_python.pdf', dpi=300, bbox_inches='tight')
